# %% [markdown]
# # Pre-processing script
# This script pulls SDG data from API and transforms it into csv files.
# The steps are:
# - Pull data from [API](https://unstats.un.org/SDGAPI/swagger/)
# - Join with geography
# - save as "long" table
# - pivot into "wide" format and split regional and country data

# %% [markdown]
# ### Load necessary libraries

# %%
import csv
import json
import urllib3  # allows to access a URL with python
import math
import os
import io
import collections
import hashlib
import numpy as np
import pandas as pd
import re
import xlsxwriter

# https://volderette.de/jupyter-notebook-tip-multiple-outputs/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### User parameters

# %%
release = '2019.Q2.G.01' # Make sure to have the correct release here

dir_path = os.path.dirname(os.path.realpath('__file__'))
print(dir_path)

wd_dir = r'../../'
print('data inputs dir: ' + wd_dir)
# Out:
# C:\Users\L.GonzalezMorales\Documents\GitHub\FIS4SDGs\notebooks\unsdPublishing
# data inputs dir: ../../

# %% [markdown]
# ## Utilities

# %% [markdown]
# #### Convert string to camelCase

# %%
def camelCase(st):
    """
    https://stackoverflow.com/questions/8347048/camelcase-every-string-any-standard-library
    
    """
    output = ''.join(x for x in st.title() if x.isalnum())
    return output[0].lower() + output[1:]

# %% [markdown]
# #### Disable insecure request warnings when using `urllib3`.

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# #### Regular expression to capture numeric values (including those in scientific notation)
# The regex is
#
# ```
# -?      # an optional -
# \d+     # a series of digits
# (?:     # start non capturing group
#   \.    # a dot
#   \d+   # a series of digits
# )?
# (?:     # start non capturing group
#   e     # "e"
#   -?    # an optional -
#   \d+   # digits
# )?
# ```

# %%
def numeric_part(v):
    numeric_part_f = re.compile(r'-?\d+(?:\.\d+)?(?:e-?\d+)?')
    x = numeric_part_f.findall(v)
    if len(x) > 0:
        return float(x[0])
    else:
        return None

# %% [markdown]
# #### Compute a hash of a dictionary

# %%
def dict_hash(d):
    out = hashlib.md5()
    for key, value in d.items():
        out.update(key.encode('utf-8'))
        out.update(value.encode('utf-8'))
    return out.hexdigest()

# %% [markdown]
# #### Get unique dictionaries in a list

# %%
def unique_dicts(dictionary_list):

    uniques_map = {}

    for d in dictionary_list:
        uniques_map[dict_hash(d)] = d

    return list(uniques_map.values())

# %% [markdown]
# #### Extract subset of key-value pairs from Python dictionary object

# %%
def subdict_list(dict_list, keys_list, exclude = False):
    sub_d_list = []
    if exclude:
        for d in dict_list:
            sub_d= {k: d[k] for k in d.keys() if k not in keys_list}
            sub_d_list.append(sub_d)
    else:
        for d in dict_list:
            sub_d= {k: d[k] for k in keys_list}
            sub_d_list.append(sub_d)
    
    return sub_d_list

# %% [markdown]
# #### Get a dict from a list based on something inside the dict

# %%
def select_dict(dict_list, k, v):
    selected = []
    for d in dict_list:
        if d[k] == v:
            selected.append(d)
    return selected

# %% [markdown]
# ### List of countries to be plotted on a map (with XY coordinates)

# %%
def countryListXY(file):
    
    countryListXY = []
    
    with open(file, newline = '', encoding='latin-1') as countryList:                                                                                          
        countryList = csv.DictReader(countryList, delimiter='\t')
        for row in countryList:
            countryListXY.append(dict(row))
            
    countryListXY = pd.DataFrame(countryListXY).astype({'M49':'str'})
    
    return(countryListXY)

    #print(countryListXY[1])
    #for c in countryListXY:

# %%
countryListXY(wd_dir + 'globalResources/refAreas.txt').head(10)
# Out:
#   Country_Profile ISO3 M49 UN_Member             X             Y  \
# 0               1  AFG   4         1   66.02688198   33.83160199
# 1               1  ALB   8         1   20.06660928   41.13897007
# 2               1  ATA  10         0   21.47585697  -80.40897662
# 3               1  DZA  12         1   2.678164227   28.15940032
# 4               1  ASM  16         0  -170.7187269  -14.30587306
# 5               1  AND  20         1   1.576257417   42.54548611
# 6               1  AGO  24         1   17.57817062  -12.33724746
# 7               1  ATG  28         1   -61.7999755   17.07761471
# 8               1  AZE  31         1   50.01064725   40.39229544
# 9               1  ARG  32         1  -65.14563274  -35.19446255
#
#               areaName
# 0          Afghanistan
# 1              Albania
# 2           Antarctica
# 3              Algeria
# 4       American Samoa
# 5              Andorra
# 6               Angola
# 7  Antigua and Barbuda
# 8           Azerbaijan
# 9            Argentina

# %% [markdown]
# #### Call the endpoint of the SDG API that provides the list of hierarchical groupings of geographic Areas:

# %%
def geoAreaTree():
    http = urllib3.PoolManager()
    response = http.request('GET', "https://unstats.un.org/SDGAPI/v1/sdg/GeoArea/Tree")
    responseData = json.loads(response.data.decode('UTF-8'))
    
    return responseData

# %% [markdown]
# Note: The geoAreaTree object has various "trees" in it.  We usually use the "World" tree; however, some economic and geographic groupings are only in other trees.

# %%
print(len(geoAreaTree()))
for t in geoAreaTree():
    print('root='+t['geoAreaName'])
# Out:
# 7
# root=World
# root=Least Developed Countries (LDC)
# root=Land Locked Developing Countries (LLDC)
# root=Small Island Developing States (SIDS)
# root=Developed Regions
# root=Developing Regions
# root=Custom groupings of data providers

# %% [markdown]
# #### Traverse a hierarchical tree of geographic areas and convert it to a parent-child hierarchy table:

# %%
def flatten(tree):
    
    global hierarchy
    
    hierarchy = []
    traverse.level = 1
    traverse(tree)
    
    return pd.DataFrame(hierarchy)

# %%
def traverse(tree, parentCode=None, parentName=None):
    
    # print(' ' * traverse.level + 'Level: ' + str(traverse.level) + ', ' + tree['type'] + ', ' + str(tree['geoAreaCode']) + '-' + tree['geoAreaName'] )
    
    d = {}
    
    d['level'] = traverse.level
    d['type'] = tree['type']
    d['parentCode'] = parentCode
    d['parentName'] = parentName
    d['geoAreaCode'] = str(tree['geoAreaCode'])
    d['geoAreaName'] = tree['geoAreaName']
    
    hierarchy.append(d)
        
    if tree['children']:
        for child in tree['children']:
            traverse.level += 1
            traverse(child, str(tree['geoAreaCode']), tree['geoAreaName'])
            traverse.level -= 1
    
    return pd.DataFrame(hierarchy)

# %% [markdown]
# #### `geoAreas` holds the flattened list of geographic areas under 'World':

# %%
geoAreas = flatten(geoAreaTree()[0])
geoAreas.head()
print('...')
geoAreas.tail()
# Out:
#   geoAreaCode      geoAreaName  level parentCode       parentName     type
# 0           1            World      1       None             None   Region
# 1          10       Antarctica      2          1            World  Country
# 2           2           Africa      2          1            World   Region
# 3          15  Northern Africa      3          2           Africa   Region
# 4          12          Algeria      4         15  Northern Africa  Country
# ...
#     geoAreaCode                               geoAreaName  level parentCode  \
# 291         543  Oceania (exc. Australia and New Zealand)      3          9
# 292          62                 Central and Southern Asia      2          1
# 293         513               Europe and Northern America      2          1
# 294         747          Northern Africa and Western Asia      2          1
# 295         753            Eastern and South-Eastern Asia      2          1
#
#     parentName    type
# 291    Oceania  Region
# 292      World  Region
# 293      World  Region
# 294      World  Region
# 295      World  Region

# %% [markdown]
# ##### Temporary Fix for missing regions:

# %%
if('910' not in geoAreas['geoAreaCode']):
    d_910 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '910',
              'geoAreaName' : 'High income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_910.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('911' not in geoAreas['geoAreaCode']):
    d_911 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '911',
              'geoAreaName' : 'Low income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_911.items()})
    geoAreas = geoAreas.append(x, sort = True)

    
if('912' not in geoAreas['geoAreaCode']):
    d_912 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '912',
              'geoAreaName' : 'Lower middle economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_912.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('913' not in geoAreas['geoAreaCode']):
    d_913 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '913',
              'geoAreaName' : 'Low and middle income economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_913.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('914' not in geoAreas['geoAreaCode']):
    d_914 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '914',
              'geoAreaName' : 'Upper middle economies (WB)'
             }
    x = pd.DataFrame({k: [v] for k, v in d_914.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('135' not in geoAreas['geoAreaCode']):
    d_135 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '135',
              'geoAreaName' : 'Caucasus and Central Asia'
            }
    x = pd.DataFrame({k: [v] for k, v in d_135.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('127' not in geoAreas['geoAreaCode']):
    d_127 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '127',
              'geoAreaName' : 'Southern Asia (excluding India)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_127.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('199' not in geoAreas['geoAreaCode']):
    d_199 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '199',
              'geoAreaName' : 'Least Developed Countries (LDC)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_199.items()})
    geoAreas = geoAreas.append(x, sort = True)

if('485' not in geoAreas['geoAreaCode']):
    d_485 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '485',
              'geoAreaName' : 'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_485.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('514' not in geoAreas['geoAreaCode']):
    d_514 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '514',
              'geoAreaName' : 'Developed Regions'
            }
    x = pd.DataFrame({k: [v] for k, v in d_514.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('515' not in geoAreas['geoAreaCode']):
    d_515 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '515',
              'geoAreaName' : 'Developing Regions'
            }
    x = pd.DataFrame({k: [v] for k, v in d_515.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('518' not in geoAreas['geoAreaCode']):
    d_518 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '518',
              'geoAreaName' : 'Eastern Asia (excluding Japan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_518.items()})
    geoAreas = geoAreas.append(x, sort = True)


if('738' not in geoAreas['geoAreaCode']):
    d_738 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '738',
              'geoAreaName' : 'Sub-Saharan Africa (inc. Sudan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_738.items()})
    geoAreas = geoAreas.append(x, sort = True)

                 
if('746' not in geoAreas['geoAreaCode']):
    d_746 = {'level' : 1,
              'type' : 'Group',
              'parentCode' : None,
              'parentName' : None,
              'geoAreaCode' : '746',
              'geoAreaName' : 'Northern Africa (exc. Sudan)'
            }
    x = pd.DataFrame({k: [v] for k, v in d_746.items()})
    geoAreas = geoAreas.append(x, sort = True)

#==================================

geoAreas = geoAreas.reset_index(drop=True)

geoAreas.tail(20)
# Out:
#     geoAreaCode                                        geoAreaName  level  \
# 290         876                          Wallis and Futuna Islands      4
# 291         543           Oceania (exc. Australia and New Zealand)      3
# 292          62                          Central and Southern Asia      2
# 293         513                        Europe and Northern America      2
# 294         747                   Northern Africa and Western Asia      2
# 295         753                     Eastern and South-Eastern Asia      2
# 296         910                         High income economies (WB)      1
# 297         911                          Low income economies (WB)      1
# 298         912                        Lower middle economies (WB)      1
# 299         913               Low and middle income economies (WB)      1
# 300         914                        Upper middle economies (WB)      1
# 301         135                          Caucasus and Central Asia      1
# 302         127                    Southern Asia (excluding India)      1
# 303         199                    Least Developed Countries (LDC)      1
# 304         485  Western Asia (exc. Armenia, Azerbaijan, Cyprus...      1
# 305         514                                  Developed Regions      1
# 306         515                                 Developing Regions      1
# 307         518                     Eastern Asia (excluding Japan)      1
# 308         738                    Sub-Saharan Africa (inc. Sudan)      1
# 309         746                       Northern Africa (exc. Sudan)      1
#
#     parentCode parentName     type
# 290         61  Polynesia  Country
# 291          9    Oceania   Region
# 292          1      World   Region
# 293          1      World   Region
# 294          1      World   Region
# 295          1      World   Region
# 296       None       None    Group
# 297       None       None    Group
# 298       None       None    Group
# 299       None       None    Group
# 300       None       None    Group
# 301       None       None    Group
# 302       None       None    Group
# 303       None       None    Group
# 304       None       None    Group
# 305       None       None    Group
# 306       None       None    Group
# 307       None       None    Group
# 308       None       None    Group
# 309       None       None    Group

# %% [markdown]
# #### Merge coordinates and list of geographic areas in SDG database

# %%
geoAreas_dict = geoAreas.to_dict('records')
geoAreas_dict[0]
# Out:
# {'geoAreaCode': '1',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region'}

# %%
def geoareasXY(geoareas,coordinates_file):
    
    xy = countryListXY(coordinates_file)
    
    x = pd.merge(geoareas,xy.loc[:, xy.columns != 'geoAreaName'],
         how='outer',
         left_on='geoAreaCode', right_on='M49')
    x['order'] = x['geoAreaCode']
    x['order'] = x['order'].astype(float)
    x = x.sort_values('order')
    del x['order']
    del x['M49']
    
    x = x.reset_index(drop=True)
    
    x = x.to_dict('records')
    
    
    x_clean = []
    
    for i in x:
        i['geoAreaCode'] = i['geoAreaCode'].zfill(3)
        if i['parentCode']:
            i['parentCode'] = i['parentCode'].zfill(3)
        x_clean.append({k: None if str(v) == 'nan' else v for k, v in i.items()})
    
    
    
    return(x_clean)

# x.to_excel('test.xlsx', engine ='xlsxwriter')

# %%
geoareasXY(geoAreas, wd_dir + 'globalResources/refAreas.txt')[0:3]
# Out:
# [{'geoAreaCode': '001',
#   'geoAreaName': 'World',
#   'level': 1,
#   'parentCode': None,
#   'parentName': None,
#   'type': 'Region',
#   'Country_Profile': None,
#   'ISO3': None,
#   'UN_Member': None,
#   'X': None,
#   'Y': None,
#   'areaName': None},
#  {'geoAreaCode': '002',
#   'geoAreaName': 'Africa',
#   'level': 2,
#   'parentCode': '001',
#   'parentName': 'World',
#   'type': 'Region',
#   'Country_Profile': None,
#   'ISO3': None,
#   'UN_Member': None,
#   'X': None,
#   'Y': None,
#   'areaName': None},
#  {'geoAreaCode': '004',
#   'geoAreaName': 'Afghanistan',
#   'level': 4,
#   'parentCode': '034',
#   'parentName': 'Southern Asia',
#   'type': 'Country',
#   'Country_Profile': '1',
#   'ISO3': 'AFG',
#   'UN_Member': '1',
#   'X': '66.02688198',
#   'Y': '33.83160199',
#   'areaName': 'Afghanistan'}]

# %% [markdown]
# ### Get the list of goals, targets, indicators and series

# %%
with open(wd_dir + 'globalResources/metadata.json') as json_file:  
    metadata = json.load(json_file)

# %%
metadata[0]['targets'][0]['indicators'][0]['series'][0]
# Out:
# {'code': 'SI_POV_DAY1',
#  'description': 'Proportion of population below international poverty line (%)',
#  'release': '2019.Q2.G.01',
#  'tags': ['poverty line', 'poverty', 'standard of living', 'basic needs']}

# %% [markdown]
# #### Get list of unique data series

# %%
series = []
for g in metadata:
    for t in g['targets']:
        for i in t['indicators']:
            if 'series' in i.keys():
                for s in i['series']:
                    series.append(s['code'])
series = list(set(series))

series[0:10]
# Out:
# ['SH_TRP_INTVN',
#  'SG_SCP_CNTRY',
#  'AG_LND_FRST',
#  'IS_RDP_FRGVOL',
#  'VC_DSR_HFDN',
#  'SH_FPL_INFMCU',
#  'EG_TBA_H2COAQ',
#  'EG_FEC_RNEW',
#  'SH_DTH_NCOM',
#  'SE_LGP_ACHIRE']

# %% [markdown]
# ### Get the data for each series

# %% [markdown]
# #### Verify how many pages need to be requested to get all the data for a specific series from the SDG API.

# %%
def series_request_details(seriesCode,release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2"
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    pageSize = 700
    nPages = math.floor(responseData['totalElements'] / pageSize) + 1
    totalElements = responseData['totalElements']
    
    return {'series' : seriesCode,
            'totalElements' : totalElements,
            'nPages' : nPages, 
            'pageSize' : pageSize
           }

# %%
series_request_details('SL_EMP_INJUR', release)
# Out:
# {'series': 'SL_EMP_INJUR', 'totalElements': 3353, 'nPages': 5, 'pageSize': 750}

# %% [markdown]
# #### Explore the code lists of the attributes and dimensions of a series
# Describe each attribute or dimension as a simple dictionary made of a set of `code`-`description` pairs.  For the code, use the SDMX code, and not the internal codeof the database.  Keep all labels in camelCase.

# %%
def series_code_lists(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2"
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    new_dict = {}
    
    new_dict['seriesCode'] = seriesCode
    
    for a in series_attributes:
        codelist_dict = {}
        for c in a['codes']:
            codelist_dict[c['code']] = c['description']
        new_dict[camelCase(a['id'])] = codelist_dict
    
    for d in series_dimensions:
        codelist_dict = {}
        for c in d['codes']:
            codelist_dict[c['code']] = c['description']
        new_dict[camelCase(d['id'])] = codelist_dict
        
    return new_dict

# %%
series_code_lists('SL_EMP_INJUR', release)
# Out:
# {'seriesCode': 'SL_EMP_INJUR',
#  'nature': {'C': 'Country data',
#   'CA': 'Country adjusted data',
#   'E': 'Estimated data',
#   'G': 'Global monitoring data',
#   'M': 'Modeled data',
#   'N': 'Non-relevant',
#   'NA': 'Data nature not available'},
#  'units': {'PER_100000_EMP': 'Per 100,000 employees',
#   'PER_100000_PRSN_INSR': 'Per 100,000 persons insured',
#   'PER_100000_WKRS_EMP': 'Per 100,000 workers employed'},
#  'migratoryStatus': {'_T': 'No breakdown',
#   'MIGPER': 'Migrants',
#   'NONMIG': 'Non-migrant',
#   'EUMIG': 'EU Migrants',
#   'NONEUMIG': 'Non-EU Migrants'},
#  'reportingType': {'N': 'National', 'G': 'Global'},
#  'sex': {'FEMALE': 'Female', 'MALE': 'Male', 'BOTHSEX': 'Both sexes'}}

# %% [markdown]
# #### Simplify further by presenting all the codes and their descriptions in a single table:

# %%
def series_code_lists2(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2" 
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    code_list = []
    
    for a in series_attributes:
       
        for c in a['codes']:
            new_dict = {}
            new_dict['series'] = seriesCode
            new_dict['role'] = 'attribute'
            new_dict['concept'] = camelCase(a['id'])
            new_dict['code'] = c['code']
            new_dict['sdmx'] = c['sdmx']
            new_dict['description'] = c['description']
            code_list.append(new_dict)
        
    for d in series_dimensions:
        for c in d['codes']:
            new_dict = {}
            new_dict['series'] = seriesCode
            new_dict['role'] = 'dimension'
            new_dict['concept'] = camelCase(d['id'])
            new_dict['code'] = c['code']
            new_dict['sdmx'] = c['sdmx']
            new_dict['description'] = c['description']
            code_list.append(new_dict)
        
    return pd.DataFrame(code_list)

# %%
def series_code_lists3(seriesCode, release):
    
    seriesRequest = 'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + "&pageSize=2" 
    
    http = urllib3.PoolManager()
    response = http.request('GET', seriesRequest)
    responseData = json.loads(response.data.decode('UTF-8'))
    
    series_attributes = responseData['attributes']
    series_dimensions = responseData['dimensions']
    
    concepts = []
    
    for d in series_dimensions:

        new_dict = {}
        new_dict['concept'] = camelCase(d['id'])
        new_dict['role'] = 'dimension'
        new_dict['codes'] = []
        for c in d['codes']:
            new_dict2 = {}
            new_dict2['code'] = c['code']
            new_dict2['sdmx'] = c['sdmx']
            new_dict2['description'] = c['description']
            new_dict['codes'].append(new_dict2)
        concepts.append(new_dict)
    
    for a in series_attributes:
        
        new_dict = {}
        new_dict['concept'] = camelCase(a['id'])
        new_dict['role'] = 'attribute'
        new_dict['codes'] = []
        for c in a['codes']:
            new_dict2 = {}
            new_dict2['code'] = c['code']
            new_dict2['sdmx'] = c['sdmx']
            new_dict2['description'] = c['description']
            new_dict['codes'].append(new_dict2)
        concepts.append(new_dict)
        
        
    return concepts #pd.DataFrame(code_list)

# %%
series_code_lists2('SL_EMP_INJUR', release)
series_code_lists3('SL_EMP_INJUR', release)
# Out:
#                     code          concept                   description  \
# 0                      C           nature                  Country data
# 1                     CA           nature         Country adjusted data
# 2                      E           nature                Estimated data
# 3                      G           nature        Global monitoring data
# 4                      M           nature                  Modeled data
# 5                      N           nature                  Non-relevant
# 6                     NA           nature     Data nature not available
# 7         PER_100000_EMP            units         Per 100,000 employees
# 8   PER_100000_PRSN_INSR            units   Per 100,000 persons insured
# 9    PER_100000_WKRS_EMP            units  Per 100,000 workers employed
# 10                    _T  migratoryStatus                  No breakdown
# 11                MIGPER  migratoryStatus                      Migrants
# 12                NONMIG  migratoryStatus                   Non-migrant
# 13                 EUMIG  migratoryStatus                   EU Migrants
# 14              NONEUMIG  migratoryStatus               Non-EU Migrants
# 15                     N    reportingType                      National
# 16                     G    reportingType                        Global
# 17                FEMALE              sex                        Female
# 18                  MALE              sex                          Male
# 19               BOTHSEX              sex                    Both sexes
#
#          role                  sdmx        series
# 0   attribute                     C  SL_EMP_INJUR
# 1   attribute                    CA  SL_EMP_INJUR
# 2   attribute                     E  SL_EMP_INJUR
# 3   attribute                     G  SL_EMP_INJUR
# 4   attribute                     M  SL_EMP_INJUR
# 5   attribute                     N  SL_EMP_INJUR
# 6   attribute                    NA  SL_EMP_INJUR
# 7   attribute        PER_100000_EMP  SL_EMP_INJUR
# 8   attribute  PER_100000_PRSN_INSR  SL_EMP_INJUR
# 9   attribute   PER_100000_WKRS_EMP  SL_EMP_INJUR
# 10  dimension                    _T  SL_EMP_INJUR
# 11  dimension                MIGPER  SL_EMP_INJUR
# 12  dimension                NONMIG  SL_EMP_INJUR
# 13  dimension          MS_EUMIGRANT  SL_EMP_INJUR
# 14  dimension       MS_NONEUMIGRANT  SL_EMP_INJUR
# 15  dimension                     N  SL_EMP_INJUR
# 16  dimension                     G  SL_EMP_INJUR
# 17  dimension                     F  SL_EMP_INJUR
# 18  dimension                     M  SL_EMP_INJUR
# 19  dimension                    _T  SL_EMP_INJUR
# [{'concept': 'migratoryStatus',
#   'role': 'dimension',
#   'codes': [{'code': '_T', 'sdmx': '_T', 'description': 'No breakdown'},
#    {'code': 'MIGPER', 'sdmx': 'MIGPER', 'description': 'Migrants'},
#    {'code': 'NONMIG', 'sdmx': 'NONMIG', 'description': 'Non-migrant'},
#    {'code': 'EUMIG', 'sdmx': 'MS_EUMIGRANT', 'description': 'EU Migrants'},
#    {'code': 'NONEUMIG',
#     'sdmx': 'MS_NONEUMIGRANT',
#     'description': 'Non-EU Migrants'}]},
#  {'concept': 'reportingType',
#   'role': 'dimension',
#   'codes': [{'code': 'N', 'sdmx': 'N', 'description': 'National'},
#    {'code': 'G', 'sdmx': 'G', 'description': 'Global'}]},
#  {'concept': 'sex',
#   'role': 'dimension',
#   'codes': [{'code': 'FEMALE', 'sdmx': 'F', 'description': 'Female'},
#    {'code': 'MALE', 'sdmx': 'M', 'description': 'Male'},
#    {'code': 'BOTHSEX', 'sdmx': '_T', 'description': 'Both sexes'}]},
#  {'concept': 'nature',
#   'role': 'attribute',
#   'codes': [{'code': 'C', 'sdmx': 'C', 'description': 'Country data'},
#    {'code': 'CA', 'sdmx': 'CA', 'description': 'Country adjusted data'},
#    {'code': 'E', 'sdmx': 'E', 'description': 'Estimated data'},
#    {'code': 'G', 'sdmx': 'G', 'description': 'Global monitoring data'},
#    {'code': 'M', 'sdmx': 'M', 'description': 'Modeled data'},
#    {'code': 'N', 'sdmx': 'N', 'description': 'Non-relevant'},
#    {'code': 'NA', 'sdmx': 'NA', 'description': 'Data nature not available'}]},
#  {'concept': 'units',
#   'role': 'attribute',
#   'codes': [{'code': 'PER_100000_EMP',
#     'sdmx': 'PER_100000_EMP',
#     'description': 'Per 100,000 employees'},
#    {'code': 'PER_100000_PRSN_INSR',
#     'sdmx': 'PER_100000_PRSN_INSR',
#     'description': 'Per 100,000 persons insured'},
#    {'code': 'PER_100000_WKRS_EMP',
#     'sdmx': 'PER_100000_WKRS_EMP',
#     'description': 'Per 100,000 workers employed'}]}]

# %% [markdown]
# #### Build query string to collect data for a specific series from the global SDG API

# %%
def series_query(seriesCode, release, page, pageSize):
    queryString =  r'https://unstats.un.org/SDGAPI/v1/sdg/Series/Data?seriesCode=' + seriesCode + '&releaseCode=' + release + '&page=' + str(page) + '&pageSize=' + str(pageSize)
    http = urllib3.PoolManager()
    response = http.request('GET', queryString)
    responseData =  json.loads(response.data.decode('UTF-8'))
    return(responseData)

# %% [markdown]
# #### Get data for a specific series from the API
# *(!) Notice that a data point may appear more than once if it belongs to a "multi-purpose indicator"*

# %%
def series_data(seriesCode, release):
    x = series_request_details(seriesCode,release)
    series_data = []
    if x['totalElements'] > 0:
        for p in range(x['nPages']):
            print("---Series " + seriesCode + ": Processing page " + str(p+1) + " of " + str(x['nPages']))
            responseData =  series_query(seriesCode, release, p+1, x['pageSize'])
            if len(responseData['data'])>0:
                series_data = series_data + responseData['data'] 
    return series_data

# %%
x = series_data('SL_EMP_INJUR',release)
if len(x) > 0:
    x[0]
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 5
# ---Series SL_EMP_INJUR: Processing page 2 of 5
# ---Series SL_EMP_INJUR: Processing page 3 of 5
# ---Series SL_EMP_INJUR: Processing page 4 of 5
# ---Series SL_EMP_INJUR: Processing page 5 of 5
# {'goal': ['8'],
#  'target': ['8.8'],
#  'indicator': ['8.8.1'],
#  'series': 'SL_EMP_INJUR',
#  'seriesDescription': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'seriesCount': '3353',
#  'geoAreaCode': '12',
#  'geoAreaName': 'Algeria',
#  'timePeriodStart': 2000.0,
#  'value': '1541.5',
#  'valueType': 'Float',
#  'time_detail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': ['Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons'],
#  'attributes': {'Nature': 'C', 'Units': 'PER_100000_EMP'},
#  'dimensions': {'Sex': 'BOTHSEX',
#   'Migratory status': '_T',
#   'Reporting Type': 'G'}}

# %% [markdown]
# #### Flatten the dictionary, extracting individual attributes and dimensions as key-value pairs in their own right.
# Also convert the years (`timePeriod`) variable to `int`

# %%
geo = geoareasXY(geoAreas, wd_dir + 'globalResources/refAreas.txt')
geo[0]
# Out:
# {'geoAreaCode': '001',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region',
#  'Country_Profile': None,
#  'ISO3': None,
#  'UN_Member': None,
#  'X': None,
#  'Y': None,
#  'areaName': None}

# %%
def flat_series_data(seriesCode,release):

    codeLists = series_code_lists3(seriesCode,release)
    
    series_data(seriesCode,release)
    new_x = []
    for d in series_data(seriesCode,release):
        new_d = {}
        for key, value in d.items():
            if type(value) is list:
                new_d[key] = ', '.join(value)
            elif type(value) is dict:
                for k, v in value.items():
                    new_d[camelCase(k+' Code')] = v
                    for cl in codeLists:
                        if cl['concept'] == camelCase(k):
                            for c in cl['codes']:
                                if c['code'] == v:
                                    new_d[camelCase(k+' Desc')] = c['description']
                                    new_d[camelCase(k+' Code')] = c['sdmx']
                                    break
                            break
            elif key == 'time_detail':
                new_d[camelCase(key)] = value
            elif key == 'timePeriodStart':
                new_d['timePeriod'] = int(value)
            elif key == 'series':
                new_d['seriesCode'] = value
            elif key == 'seriesDescription':
                new_d['seriesDesc'] = value
            elif key == 'geoAreaCode':
                new_d['geoAreaCode'] = str(value).zfill(3)
            else:
                new_d[key] = value

        new_d['value_numeric_part'] = numeric_part(new_d['value'])
        new_d['value_is_censored'] = (new_d['valueType'] != 'Float')
        new_d['value_detail'] = new_d['value']

        del new_d['value']
        del new_d['valueType']
        del new_d['seriesCount']

        new_x.append(new_d)

    return new_x

# %%
x = flat_series_data('SL_EMP_INJUR',release)
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 5
# ---Series SL_EMP_INJUR: Processing page 2 of 5
# ---Series SL_EMP_INJUR: Processing page 3 of 5
# ---Series SL_EMP_INJUR: Processing page 4 of 5
# ---Series SL_EMP_INJUR: Processing page 5 of 5

# %%
x[0]
# Out:
# {'goal': '8',
#  'target': '8.8',
#  'indicator': '8.8.1',
#  'seriesCode': 'SL_EMP_INJUR',
#  'seriesDesc': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'geoAreaCode': '012',
#  'geoAreaName': 'Algeria',
#  'timePeriod': 2000,
#  'timeDetail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': 'Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons',
#  'natureCode': 'C',
#  'natureDesc': 'Country data',
#  'unitsCode': 'PER_100000_EMP',
#  'unitsDesc': 'Per 100,000 employees',
#  'sexCode': '_T',
#  'sexDesc': 'Both sexes',
#  'migratoryStatusCode': '_T',
#  'migratoryStatusDesc': 'No breakdown',
#  'reportingTypeCode': 'G',
#  'reportingTypeDesc': 'Global',
#  'value_numeric_part': 1541.5,
#  'value_is_censored': False,
#  'value_detail': '1541.5'}

# %% [markdown]
# ##### Select distinct indicator-series that are included in the dataset
#
# When there is a 'multi-purpose indicator', the same data series is part of two different goal-target-indicator specification.

# %%
indicator_series = unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
)

# %% [markdown]
# Now, for each `indicator_series`, we want to build a json file that contains all the necessary information to be published as a layer. This requires to build a tree structure with the following levels:
# - Information about the goal, target, indicator, and series
# - Information about the geographic reference area
# - Data grouped by time period

# %%
series = 'SL_EMP_INJUR'

x = flat_series_data(series,release)

indicator_series =  unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
)
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 5
# ---Series SL_EMP_INJUR: Processing page 2 of 5
# ---Series SL_EMP_INJUR: Processing page 3 of 5
# ---Series SL_EMP_INJUR: Processing page 4 of 5
# ---Series SL_EMP_INJUR: Processing page 5 of 5

# %%
x[0]
geo[0]
# Out:
# {'goal': '8',
#  'target': '8.8',
#  'indicator': '8.8.1',
#  'seriesCode': 'SL_EMP_INJUR',
#  'seriesDesc': 'Non-fatal occupational injuries among employees, by sex and migrant status (per 100,000 employees)',
#  'geoAreaCode': '012',
#  'geoAreaName': 'Algeria',
#  'timePeriod': 2000,
#  'timeDetail': None,
#  'source': 'ILOSTAT - ADM-IR - Insurance records',
#  'footnotes': 'Coverage of occupational injuries: Compensated injuries | Reference group coverage: Insured persons',
#  'natureCode': 'C',
#  'natureDesc': 'Country data',
#  'unitsCode': 'PER_100000_EMP',
#  'unitsDesc': 'Per 100,000 employees',
#  'sexCode': '_T',
#  'sexDesc': 'Both sexes',
#  'migratoryStatusCode': '_T',
#  'migratoryStatusDesc': 'No breakdown',
#  'reportingTypeCode': 'G',
#  'reportingTypeDesc': 'Global',
#  'value_numeric_part': 1541.5,
#  'value_is_censored': False,
#  'value_detail': '1541.5'}
# {'geoAreaCode': '001',
#  'geoAreaName': 'World',
#  'level': 1,
#  'parentCode': None,
#  'parentName': None,
#  'type': 'Region',
#  'Country_Profile': None,
#  'ISO3': None,
#  'UN_Member': None,
#  'X': None,
#  'Y': None,
#  'areaName': None}

# %%
def get_data_to_json(series, release):
    
    x = flat_series_data(series,release)

    indicator_series =  unique_dicts(subdict_list(x,['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc'])
    )

    dataset = []
    for s in indicator_series:
        d = s.copy()
        d['release'] = release
        indicator = d['indicator']
        data = select_dict(x, 'indicator', indicator)
        d['refAreas'] = geo.copy()
        for g in d['refAreas']:
            g_data = subdict_list(select_dict(data, 'geoAreaCode', g['geoAreaCode']),
                                  ['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc','geoAreaCode', 'geoAreaName'], 
                                  exclude = True)
            g['data'] = g_data

        file_name = release + '\Indicator_' + indicator + '_Series_' + d['seriesCode'] + '.json'

        with open(wd_dir + r'data\unsd\\' + file_name, 'w') as f:
            json.dump(d, f, indent=4)
        
        print('created file ' + file_name)

# %%
get_data_to_json(series, release)
# Out:
# ---Series SL_EMP_INJUR: Processing page 1 of 5
# ---Series SL_EMP_INJUR: Processing page 2 of 5
# ---Series SL_EMP_INJUR: Processing page 3 of 5
# ---Series SL_EMP_INJUR: Processing page 4 of 5
# ---Series SL_EMP_INJUR: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_8.8.1_Series_SL_EMP_INJUR.json

# %% [markdown]
# #### Produce 'long' files for each indicator/series combination
# (Notice that multi-purpose indicators need to be split)

# %%
series = []
for g in metadata:
    for t in g['targets']:
        for i in t['indicators']:
            if 'series' in i.keys():
                for s in i['series']:
                    series.append(s['code'])
series = list(set(series))

series.sort()

# %%
for i in range(len(series)):
    print('series no. ' + str(i))
    get_data_to_json(series = series[i], release = release)
# Out:
# series no. 0
# ---Series AG_FPA_CFPI: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_2.c.1_Series_AG_FPA_CFPI.json
# series no. 1
# ---Series AG_FPA_COMM: Processing page 1 of 4
# ---Series AG_FPA_COMM: Processing page 2 of 4
# ---Series AG_FPA_COMM: Processing page 3 of 4
# ---Series AG_FPA_COMM: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_2.c.1_Series_AG_FPA_COMM.json
# series no. 2
# ---Series AG_LND_DGRD: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_15.3.1_Series_AG_LND_DGRD.json
# series no. 3
# ---Series AG_LND_FRST: Processing page 1 of 2
# ---Series AG_LND_FRST: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.1.1_Series_AG_LND_FRST.json
# series no. 4
# ---Series AG_LND_FRSTBIOPHA: Processing page 1 of 2
# ---Series AG_LND_FRSTBIOPHA: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.2.1_Series_AG_LND_FRSTBIOPHA.json
# series no. 5
# ---Series AG_LND_FRSTCERT: Processing page 1 of 3
# ---Series AG_LND_FRSTCERT: Processing page 2 of 3
# ---Series AG_LND_FRSTCERT: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_15.2.1_Series_AG_LND_FRSTCERT.json
# series no. 6
# ---Series AG_LND_FRSTCHG: Processing page 1 of 2
# ---Series AG_LND_FRSTCHG: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.2.1_Series_AG_LND_FRSTCHG.json
# series no. 7
# ---Series AG_LND_FRSTMGT: Processing page 1 of 2
# ---Series AG_LND_FRSTMGT: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.2.1_Series_AG_LND_FRSTMGT.json
# series no. 8
# ---Series AG_LND_FRSTN: Processing page 1 of 2
# ---Series AG_LND_FRSTN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.1.1_Series_AG_LND_FRSTN.json
# series no. 9
# ---Series AG_LND_FRSTPRCT: Processing page 1 of 2
# ---Series AG_LND_FRSTPRCT: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.2.1_Series_AG_LND_FRSTPRCT.json
# series no. 10
# ---Series AG_LND_TOTL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_15.1.1_Series_AG_LND_TOTL.json
# series no. 11
# ---Series AG_PRD_AGVAS: Processing page 1 of 8
# ---Series AG_PRD_AGVAS: Processing page 2 of 8
# ---Series AG_PRD_AGVAS: Processing page 3 of 8
# ---Series AG_PRD_AGVAS: Processing page 4 of 8
# ---Series AG_PRD_AGVAS: Processing page 5 of 8
# ---Series AG_PRD_AGVAS: Processing page 6 of 8
# ---Series AG_PRD_AGVAS: Processing page 7 of 8
# ---Series AG_PRD_AGVAS: Processing page 8 of 8
# created file 2019.Q2.G.01\Indicator_2.a.1_Series_AG_PRD_AGVAS.json
# series no. 12
# ---Series AG_PRD_FIESSI: Processing page 1 of 2
# ---Series AG_PRD_FIESSI: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_2.1.2_Series_AG_PRD_FIESSI.json
# series no. 13
# ---Series AG_PRD_FIESSIN: Processing page 1 of 2
# ---Series AG_PRD_FIESSIN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_2.1.2_Series_AG_PRD_FIESSIN.json
# series no. 14
# ---Series AG_PRD_ORTIND: Processing page 1 of 8
# ---Series AG_PRD_ORTIND: Processing page 2 of 8
# ---Series AG_PRD_ORTIND: Processing page 3 of 8
# ---Series AG_PRD_ORTIND: Processing page 4 of 8
# ---Series AG_PRD_ORTIND: Processing page 5 of 8
# ---Series AG_PRD_ORTIND: Processing page 6 of 8
# ---Series AG_PRD_ORTIND: Processing page 7 of 8
# ---Series AG_PRD_ORTIND: Processing page 8 of 8
# created file 2019.Q2.G.01\Indicator_2.a.1_Series_AG_PRD_ORTIND.json
# series no. 15
# ---Series AG_PRD_XSUBDY: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_2.b.1_Series_AG_PRD_XSUBDY.json
# series no. 16
# ---Series AG_XPD_AGSGB: Processing page 1 of 8
# ---Series AG_XPD_AGSGB: Processing page 2 of 8
# ---Series AG_XPD_AGSGB: Processing page 3 of 8
# ---Series AG_XPD_AGSGB: Processing page 4 of 8
# ---Series AG_XPD_AGSGB: Processing page 5 of 8
# ---Series AG_XPD_AGSGB: Processing page 6 of 8
# ---Series AG_XPD_AGSGB: Processing page 7 of 8
# ---Series AG_XPD_AGSGB: Processing page 8 of 8
# created file 2019.Q2.G.01\Indicator_2.a.1_Series_AG_XPD_AGSGB.json
# series no. 17
# ---Series BX_TRF_PWKR: Processing page 1 of 8
# ---Series BX_TRF_PWKR: Processing page 2 of 8
# ---Series BX_TRF_PWKR: Processing page 3 of 8
# ---Series BX_TRF_PWKR: Processing page 4 of 8
# ---Series BX_TRF_PWKR: Processing page 5 of 8
# ---Series BX_TRF_PWKR: Processing page 6 of 8
# ---Series BX_TRF_PWKR: Processing page 7 of 8
# ---Series BX_TRF_PWKR: Processing page 8 of 8
# created file 2019.Q2.G.01\Indicator_17.3.2_Series_BX_TRF_PWKR.json
# series no. 18
# ---Series DC_FTA_TOTAL: Processing page 1 of 5
# ---Series DC_FTA_TOTAL: Processing page 2 of 5
# ---Series DC_FTA_TOTAL: Processing page 3 of 5
# ---Series DC_FTA_TOTAL: Processing page 4 of 5
# ---Series DC_FTA_TOTAL: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_17.9.1_Series_DC_FTA_TOTAL.json
# series no. 19
# ---Series DC_ODA_BDVDL: Processing page 1 of 2
# ---Series DC_ODA_BDVDL: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.a.1_Series_DC_ODA_BDVDL.json
# created file 2019.Q2.G.01\Indicator_15.b.1_Series_DC_ODA_BDVDL.json
# series no. 20
# ---Series DC_ODA_BDVL: Processing page 1 of 8
# ---Series DC_ODA_BDVL: Processing page 2 of 8
# ---Series DC_ODA_BDVL: Processing page 3 of 8
# ---Series DC_ODA_BDVL: Processing page 4 of 8
# ---Series DC_ODA_BDVL: Processing page 5 of 8
# ---Series DC_ODA_BDVL: Processing page 6 of 8
# ---Series DC_ODA_BDVL: Processing page 7 of 8
# ---Series DC_ODA_BDVL: Processing page 8 of 8
# created file 2019.Q2.G.01\Indicator_15.a.1_Series_DC_ODA_BDVL.json
# created file 2019.Q2.G.01\Indicator_15.b.1_Series_DC_ODA_BDVL.json
# series no. 21
# ---Series DC_ODA_LDCG: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_LDCG.json
# series no. 22
# ---Series DC_ODA_LDCS: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_LDCS.json
# series no. 23
# ---Series DC_ODA_LLDC: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_LLDC.json
# series no. 24
# ---Series DC_ODA_LLDCG: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_LLDCG.json
# series no. 25
# ---Series DC_ODA_SIDS: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_SIDS.json
# series no. 26
# ---Series DC_ODA_SIDSG: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_SIDSG.json
# series no. 27
# ---Series DC_ODA_TOTG: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_TOTG.json
# series no. 28
# ---Series DC_ODA_TOTGGE: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_TOTGGE.json
# series no. 29
# ---Series DC_ODA_TOTL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_TOTL.json
# series no. 30
# ---Series DC_ODA_TOTLGE: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_17.2.1_Series_DC_ODA_TOTLGE.json
# series no. 31
# ---Series DC_TOF_AGRL: Processing page 1 of 5
# ---Series DC_TOF_AGRL: Processing page 2 of 5
# ---Series DC_TOF_AGRL: Processing page 3 of 5
# ---Series DC_TOF_AGRL: Processing page 4 of 5
# ---Series DC_TOF_AGRL: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_2.a.2_Series_DC_TOF_AGRL.json
# series no. 32
# ---Series DC_TOF_HLTHL: Processing page 1 of 5
# ---Series DC_TOF_HLTHL: Processing page 2 of 5
# ---Series DC_TOF_HLTHL: Processing page 3 of 5
# ---Series DC_TOF_HLTHL: Processing page 4 of 5
# ---Series DC_TOF_HLTHL: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_3.b.2_Series_DC_TOF_HLTHL.json
# series no. 33
# ---Series DC_TOF_HLTHNT: Processing page 1 of 2
# ---Series DC_TOF_HLTHNT: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_3.b.2_Series_DC_TOF_HLTHNT.json
# series no. 34
# ---Series DC_TOF_INFRAL: Processing page 1 of 5
# ---Series DC_TOF_INFRAL: Processing page 2 of 5
# ---Series DC_TOF_INFRAL: Processing page 3 of 5
# ---Series DC_TOF_INFRAL: Processing page 4 of 5
# ---Series DC_TOF_INFRAL: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_9.a.1_Series_DC_TOF_INFRAL.json
# series no. 35
# ---Series DC_TOF_SCHIPSL: Processing page 1 of 3
# ---Series DC_TOF_SCHIPSL: Processing page 2 of 3
# ---Series DC_TOF_SCHIPSL: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_4.b.1_Series_DC_TOF_SCHIPSL.json
# series no. 36
# ---Series DC_TOF_TRDCMDL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_8.a.1_Series_DC_TOF_TRDCMDL.json
# series no. 37
# ---Series DC_TOF_TRDCML: Processing page 1 of 3
# ---Series DC_TOF_TRDCML: Processing page 2 of 3
# ---Series DC_TOF_TRDCML: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_8.a.1_Series_DC_TOF_TRDCML.json
# series no. 38
# ---Series DC_TOF_TRDDBMDL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_8.a.1_Series_DC_TOF_TRDDBMDL.json
# series no. 39
# ---Series DC_TOF_TRDDBML: Processing page 1 of 3
# ---Series DC_TOF_TRDDBML: Processing page 2 of 3
# ---Series DC_TOF_TRDDBML: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_8.a.1_Series_DC_TOF_TRDDBML.json
# series no. 40
# ---Series DC_TOF_WASHL: Processing page 1 of 5
# ---Series DC_TOF_WASHL: Processing page 2 of 5
# ---Series DC_TOF_WASHL: Processing page 3 of 5
# ---Series DC_TOF_WASHL: Processing page 4 of 5
# ---Series DC_TOF_WASHL: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_6.a.1_Series_DC_TOF_WASHL.json
# series no. 41
# ---Series DC_TRF_TFDV: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_10.b.1_Series_DC_TRF_TFDV.json
# series no. 42
# ---Series DC_TRF_TOTDL: Processing page 1 of 2
# ---Series DC_TRF_TOTDL: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_10.b.1_Series_DC_TRF_TOTDL.json
# series no. 43
# ---Series DC_TRF_TOTL: Processing page 1 of 4
# ---Series DC_TRF_TOTL: Processing page 2 of 4
# ---Series DC_TRF_TOTL: Processing page 3 of 4
# ---Series DC_TRF_TOTL: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_10.b.1_Series_DC_TRF_TOTL.json
# series no. 44
# ---Series DT_TDS_DECT: Processing page 1 of 5
# ---Series DT_TDS_DECT: Processing page 2 of 5
# ---Series DT_TDS_DECT: Processing page 3 of 5
# ---Series DT_TDS_DECT: Processing page 4 of 5
# ---Series DT_TDS_DECT: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_17.4.1_Series_DT_TDS_DECT.json
# series no. 45
# ---Series EG_EGY_CLEAN: Processing page 1 of 2
# ---Series EG_EGY_CLEAN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_7.1.2_Series_EG_EGY_CLEAN.json
# series no. 46
# ---Series EG_EGY_PRIM: Processing page 1 of 6
# ---Series EG_EGY_PRIM: Processing page 2 of 6
# ---Series EG_EGY_PRIM: Processing page 3 of 6
# ---Series EG_EGY_PRIM: Processing page 4 of 6
# ---Series EG_EGY_PRIM: Processing page 5 of 6
# ---Series EG_EGY_PRIM: Processing page 6 of 6
# created file 2019.Q2.G.01\Indicator_7.3.1_Series_EG_EGY_PRIM.json
# series no. 47
# ---Series EG_ELC_ACCS: Processing page 1 of 27
# ---Series EG_ELC_ACCS: Processing page 2 of 27
# ---Series EG_ELC_ACCS: Processing page 3 of 27
# ---Series EG_ELC_ACCS: Processing page 4 of 27
# ---Series EG_ELC_ACCS: Processing page 5 of 27
# ---Series EG_ELC_ACCS: Processing page 6 of 27
# ---Series EG_ELC_ACCS: Processing page 7 of 27
# ---Series EG_ELC_ACCS: Processing page 8 of 27
# ---Series EG_ELC_ACCS: Processing page 9 of 27
# ---Series EG_ELC_ACCS: Processing page 10 of 27
# ---Series EG_ELC_ACCS: Processing page 11 of 27
# ---Series EG_ELC_ACCS: Processing page 12 of 27
# ---Series EG_ELC_ACCS: Processing page 13 of 27
# ---Series EG_ELC_ACCS: Processing page 14 of 27
# ---Series EG_ELC_ACCS: Processing page 15 of 27
# ---Series EG_ELC_ACCS: Processing page 16 of 27
# ---Series EG_ELC_ACCS: Processing page 17 of 27
# ---Series EG_ELC_ACCS: Processing page 18 of 27
# ---Series EG_ELC_ACCS: Processing page 19 of 27
# ---Series EG_ELC_ACCS: Processing page 20 of 27
# ---Series EG_ELC_ACCS: Processing page 21 of 27
# ---Series EG_ELC_ACCS: Processing page 22 of 27
# ---Series EG_ELC_ACCS: Processing page 23 of 27
# ---Series EG_ELC_ACCS: Processing page 24 of 27
# ---Series EG_ELC_ACCS: Processing page 25 of 27
# ---Series EG_ELC_ACCS: Processing page 26 of 27
# ---Series EG_ELC_ACCS: Processing page 27 of 27
# created file 2019.Q2.G.01\Indicator_7.1.1_Series_EG_ELC_ACCS.json
# series no. 48
# ---Series EG_FEC_RNEW: Processing page 1 of 7
# ---Series EG_FEC_RNEW: Processing page 2 of 7
# ---Series EG_FEC_RNEW: Processing page 3 of 7
# ---Series EG_FEC_RNEW: Processing page 4 of 7
# ---Series EG_FEC_RNEW: Processing page 5 of 7
# ---Series EG_FEC_RNEW: Processing page 6 of 7
# ---Series EG_FEC_RNEW: Processing page 7 of 7
# created file 2019.Q2.G.01\Indicator_7.2.1_Series_EG_FEC_RNEW.json
# series no. 49
# ---Series EG_IFF_RANDN: Processing page 1 of 3
# ---Series EG_IFF_RANDN: Processing page 2 of 3
# ---Series EG_IFF_RANDN: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_7.a.1_Series_EG_IFF_RANDN.json
# series no. 50
# ---Series EG_TBA_H2CO: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.5.2_Series_EG_TBA_H2CO.json
# series no. 51
# ---Series EG_TBA_H2COAQ: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.5.2_Series_EG_TBA_H2COAQ.json
# series no. 52
# ---Series EG_TBA_H2CORL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.5.2_Series_EG_TBA_H2CORL.json
# series no. 53
# ---Series EN_ATM_CO2: Processing page 1 of 5
# ---Series EN_ATM_CO2: Processing page 2 of 5
# ---Series EN_ATM_CO2: Processing page 3 of 5
# ---Series EN_ATM_CO2: Processing page 4 of 5
# ---Series EN_ATM_CO2: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_9.4.1_Series_EN_ATM_CO2.json
# series no. 54
# ---Series EN_ATM_CO2GDP: Processing page 1 of 5
# ---Series EN_ATM_CO2GDP: Processing page 2 of 5
# ---Series EN_ATM_CO2GDP: Processing page 3 of 5
# ---Series EN_ATM_CO2GDP: Processing page 4 of 5
# ---Series EN_ATM_CO2GDP: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_9.4.1_Series_EN_ATM_CO2GDP.json
# series no. 55
# ---Series EN_ATM_CO2MVA: Processing page 1 of 5
# ---Series EN_ATM_CO2MVA: Processing page 2 of 5
# ---Series EN_ATM_CO2MVA: Processing page 3 of 5
# ---Series EN_ATM_CO2MVA: Processing page 4 of 5
# ---Series EN_ATM_CO2MVA: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_9.4.1_Series_EN_ATM_CO2MVA.json
# series no. 56
# ---Series EN_ATM_PM25: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_11.6.2_Series_EN_ATM_PM25.json
# series no. 57
# ---Series EN_H2O_GRAMBQ: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.3.2_Series_EN_H2O_GRAMBQ.json
# series no. 58
# ---Series EN_H2O_OPAMBQ: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.3.2_Series_EN_H2O_OPAMBQ.json
# series no. 59
# ---Series EN_H2O_RVAMBQ: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.3.2_Series_EN_H2O_RVAMBQ.json
# series no. 60
# ---Series EN_H2O_WBAMBQ: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.3.2_Series_EN_H2O_WBAMBQ.json
# series no. 61
# ---Series EN_LND_SLUM: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_11.1.1_Series_EN_LND_SLUM.json
# series no. 62
# ---Series EN_MAT_DOMCMPC: Processing page 1 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 2 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 3 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 4 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 5 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 6 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 7 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 8 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 9 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 10 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 11 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 12 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 13 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 14 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 15 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 16 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 17 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 18 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 19 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 20 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 21 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 22 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 23 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 24 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 25 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 26 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 27 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 28 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 29 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 30 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 31 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 32 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 33 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 34 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 35 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 36 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 37 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 38 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 39 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 40 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 41 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 42 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 43 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 44 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 45 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 46 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 47 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 48 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 49 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 50 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 51 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 52 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 53 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 54 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 55 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 56 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 57 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 58 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 59 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 60 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 61 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 62 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 63 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 64 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 65 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 66 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 67 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 68 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 69 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 70 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 71 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 72 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 73 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 74 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 75 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 76 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 77 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 78 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 79 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 80 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 81 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 82 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 83 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 84 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 85 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 86 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 87 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 88 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 89 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 90 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 91 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 92 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 93 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 94 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 95 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 96 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 97 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 98 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 99 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 100 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 101 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 102 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 103 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 104 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 105 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 106 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 107 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 108 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 109 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 110 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 111 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 112 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 113 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 114 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 115 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 116 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 117 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 118 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 119 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 120 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 121 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 122 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 123 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 124 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 125 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 126 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 127 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 128 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 129 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 130 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 131 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 132 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 133 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 134 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 135 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 136 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 137 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 138 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 139 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 140 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 141 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 142 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 143 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 144 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 145 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 146 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 147 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 148 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 149 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 150 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 151 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 152 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 153 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 154 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 155 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 156 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 157 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 158 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 159 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 160 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 161 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 162 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 163 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 164 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 165 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 166 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 167 of 168
# ---Series EN_MAT_DOMCMPC: Processing page 168 of 168
# created file 2019.Q2.G.01\Indicator_12.2.2_Series_EN_MAT_DOMCMPC.json
# created file 2019.Q2.G.01\Indicator_8.4.2_Series_EN_MAT_DOMCMPC.json
# series no. 63
# ---Series EN_MAT_DOMCMPG: Processing page 1 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 2 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 3 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 4 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 5 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 6 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 7 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 8 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 9 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 10 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 11 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 12 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 13 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 14 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 15 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 16 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 17 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 18 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 19 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 20 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 21 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 22 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 23 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 24 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 25 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 26 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 27 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 28 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 29 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 30 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 31 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 32 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 33 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 34 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 35 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 36 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 37 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 38 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 39 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 40 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 41 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 42 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 43 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 44 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 45 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 46 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 47 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 48 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 49 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 50 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 51 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 52 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 53 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 54 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 55 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 56 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 57 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 58 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 59 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 60 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 61 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 62 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 63 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 64 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 65 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 66 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 67 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 68 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 69 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 70 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 71 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 72 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 73 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 74 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 75 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 76 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 77 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 78 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 79 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 80 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 81 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 82 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 83 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 84 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 85 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 86 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 87 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 88 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 89 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 90 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 91 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 92 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 93 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 94 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 95 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 96 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 97 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 98 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 99 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 100 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 101 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 102 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 103 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 104 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 105 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 106 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 107 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 108 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 109 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 110 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 111 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 112 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 113 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 114 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 115 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 116 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 117 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 118 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 119 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 120 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 121 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 122 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 123 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 124 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 125 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 126 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 127 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 128 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 129 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 130 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 131 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 132 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 133 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 134 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 135 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 136 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 137 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 138 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 139 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 140 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 141 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 142 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 143 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 144 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 145 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 146 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 147 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 148 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 149 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 150 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 151 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 152 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 153 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 154 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 155 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 156 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 157 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 158 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 159 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 160 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 161 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 162 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 163 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 164 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 165 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 166 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 167 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 168 of 169
# ---Series EN_MAT_DOMCMPG: Processing page 169 of 169
# created file 2019.Q2.G.01\Indicator_12.2.2_Series_EN_MAT_DOMCMPG.json
# created file 2019.Q2.G.01\Indicator_8.4.2_Series_EN_MAT_DOMCMPG.json
# series no. 64
# ---Series EN_MAT_DOMCMPT: Processing page 1 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 2 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 3 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 4 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 5 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 6 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 7 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 8 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 9 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 10 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 11 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 12 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 13 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 14 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 15 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 16 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 17 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 18 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 19 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 20 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 21 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 22 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 23 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 24 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 25 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 26 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 27 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 28 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 29 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 30 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 31 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 32 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 33 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 34 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 35 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 36 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 37 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 38 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 39 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 40 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 41 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 42 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 43 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 44 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 45 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 46 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 47 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 48 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 49 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 50 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 51 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 52 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 53 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 54 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 55 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 56 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 57 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 58 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 59 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 60 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 61 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 62 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 63 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 64 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 65 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 66 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 67 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 68 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 69 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 70 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 71 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 72 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 73 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 74 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 75 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 76 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 77 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 78 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 79 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 80 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 81 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 82 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 83 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 84 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 85 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 86 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 87 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 88 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 89 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 90 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 91 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 92 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 93 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 94 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 95 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 96 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 97 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 98 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 99 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 100 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 101 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 102 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 103 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 104 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 105 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 106 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 107 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 108 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 109 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 110 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 111 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 112 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 113 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 114 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 115 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 116 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 117 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 118 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 119 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 120 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 121 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 122 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 123 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 124 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 125 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 126 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 127 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 128 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 129 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 130 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 131 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 132 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 133 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 134 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 135 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 136 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 137 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 138 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 139 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 140 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 141 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 142 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 143 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 144 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 145 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 146 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 147 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 148 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 149 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 150 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 151 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 152 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 153 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 154 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 155 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 156 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 157 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 158 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 159 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 160 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 161 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 162 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 163 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 164 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 165 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 166 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 167 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 168 of 169
# ---Series EN_MAT_DOMCMPT: Processing page 169 of 169
# created file 2019.Q2.G.01\Indicator_12.2.2_Series_EN_MAT_DOMCMPT.json
# created file 2019.Q2.G.01\Indicator_8.4.2_Series_EN_MAT_DOMCMPT.json
# series no. 65
# ---Series EN_MAT_FTPRPC: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.2.1_Series_EN_MAT_FTPRPC.json
# created file 2019.Q2.G.01\Indicator_8.4.1_Series_EN_MAT_FTPRPC.json
# series no. 66
# ---Series EN_MAT_FTPRPG: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.2.1_Series_EN_MAT_FTPRPG.json
# created file 2019.Q2.G.01\Indicator_8.4.1_Series_EN_MAT_FTPRPG.json
# series no. 67
# ---Series EN_MAT_FTPRTN: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.2.1_Series_EN_MAT_FTPRTN.json
# created file 2019.Q2.G.01\Indicator_8.4.1_Series_EN_MAT_FTPRTN.json
# series no. 68
# ---Series EN_REF_WASCOL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_11.6.1_Series_EN_REF_WASCOL.json
# series no. 69
# ---Series EN_WBE_NDETOT: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDETOT.json
# series no. 70
# ---Series EN_WBE_NDOPW: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDOPW.json
# series no. 71
# ---Series EN_WBE_NDQLGRW: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQLGRW.json
# series no. 72
# ---Series EN_WBE_NDQLOPW: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQLOPW.json
# series no. 73
# ---Series EN_WBE_NDQLRVR: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQLRVR.json
# series no. 74
# ---Series EN_WBE_NDQLTOT: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQLTOT.json
# series no. 75
# ---Series EN_WBE_NDQTGRW: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQTGRW.json
# series no. 76
# ---Series EN_WBE_NDQTOPW: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQTOPW.json
# series no. 77
# ---Series EN_WBE_NDQTRVR: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQTRVR.json
# series no. 78
# ---Series EN_WBE_NDQTTOT: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDQTTOT.json
# series no. 79
# ---Series EN_WBE_NDRV: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDRV.json
# series no. 80
# ---Series EN_WBE_NDWTL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_NDWTL.json
# series no. 81
# ---Series EN_WBE_PMNR: Processing page 1 of 5
# ---Series EN_WBE_PMNR: Processing page 2 of 5
# ---Series EN_WBE_PMNR: Processing page 3 of 5
# ---Series EN_WBE_PMNR: Processing page 4 of 5
# ---Series EN_WBE_PMNR: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_PMNR.json
# series no. 82
# ---Series EN_WBE_PMPN: Processing page 1 of 5
# ---Series EN_WBE_PMPN: Processing page 2 of 5
# ---Series EN_WBE_PMPN: Processing page 3 of 5
# ---Series EN_WBE_PMPN: Processing page 4 of 5
# ---Series EN_WBE_PMPN: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_PMPN.json
# series no. 83
# ---Series EN_WBE_PMPP: Processing page 1 of 5
# ---Series EN_WBE_PMPP: Processing page 2 of 5
# ---Series EN_WBE_PMPP: Processing page 3 of 5
# ---Series EN_WBE_PMPP: Processing page 4 of 5
# ---Series EN_WBE_PMPP: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_PMPP.json
# series no. 84
# ---Series EN_WBE_PMPR: Processing page 1 of 5
# ---Series EN_WBE_PMPR: Processing page 2 of 5
# ---Series EN_WBE_PMPR: Processing page 3 of 5
# ---Series EN_WBE_PMPR: Processing page 4 of 5
# ---Series EN_WBE_PMPR: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_6.6.1_Series_EN_WBE_PMPR.json
# series no. 85
# ---Series EN_WWT_WWDS: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.3.1_Series_EN_WWT_WWDS.json
# series no. 86
# ---Series ER_CBD_ABSCLRHS: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_15.6.1_Series_ER_CBD_ABSCLRHS.json
# series no. 87
# ---Series ER_CBD_NAGOYA: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_15.6.1_Series_ER_CBD_NAGOYA.json
# series no. 88
# ---Series ER_CBD_ORSPGRFA: Processing page 1 of 2
# ---Series ER_CBD_ORSPGRFA: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_15.6.1_Series_ER_CBD_ORSPGRFA.json
# series no. 89
# ---Series ER_CBD_PTYPGRFA: Processing page 1 of 3
# ---Series ER_CBD_PTYPGRFA: Processing page 2 of 3
# ---Series ER_CBD_PTYPGRFA: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_15.6.1_Series_ER_CBD_PTYPGRFA.json
# series no. 90
# ---Series ER_CBD_SMTA: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_15.6.1_Series_ER_CBD_SMTA.json
# series no. 91
# ---Series ER_FFS_PRTSPC: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.c.1_Series_ER_FFS_PRTSPC.json
# series no. 92
# ---Series ER_FFS_PRTSPR: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.c.1_Series_ER_FFS_PRTSPR.json
# series no. 93
# ---Series ER_FFS_PRTSST: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_12.c.1_Series_ER_FFS_PRTSST.json
# series no. 94
# ---Series ER_GRF_ANIMRCNT: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_2.5.1_Series_ER_GRF_ANIMRCNT.json
# series no. 95
# ---Series ER_GRF_PLNTSTOR: Processing page 1 of 2
# ---Series ER_GRF_PLNTSTOR: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_2.5.1_Series_ER_GRF_PLNTSTOR.json
# series no. 96
# ---Series ER_H2O_FWTL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_14.4.1_Series_ER_H2O_FWTL.json
# series no. 97
# ---Series ER_H2O_IWRMD: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.5.1_Series_ER_H2O_IWRMD.json
# series no. 98
# ---Series ER_H2O_IWRMP: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.5.1_Series_ER_H2O_IWRMP.json
# series no. 99
# ---Series ER_H2O_PARTIC: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.b.1_Series_ER_H2O_PARTIC.json
# series no. 100
# ---Series ER_H2O_PRDU: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.b.1_Series_ER_H2O_PRDU.json
# series no. 101
# ---Series ER_H2O_PROCED: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.b.1_Series_ER_H2O_PROCED.json
# series no. 102
# ---Series ER_H2O_RURP: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_6.b.1_Series_ER_H2O_RURP.json
# series no. 103
# ---Series ER_H2O_STRESS: Processing page 1 of 2
# ---Series ER_H2O_STRESS: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_6.4.2_Series_ER_H2O_STRESS.json
# series no. 104
# ---Series ER_H2O_WUEYST: Processing page 1 of 2
# ---Series ER_H2O_WUEYST: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_6.4.1_Series_ER_H2O_WUEYST.json
# series no. 105
# ---Series ER_MRN_MARIN: Processing page 1 of 1
# ...
# ---Series VC_DSR_AGLH: Processing page 15 of 19
# ---Series VC_DSR_AGLH: Processing page 16 of 19
# ---Series VC_DSR_AGLH: Processing page 17 of 19
# ---Series VC_DSR_AGLH: Processing page 18 of 19
# ---Series VC_DSR_AGLH: Processing page 19 of 19
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_AGLH.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_AGLH.json
# series no. 347
# ---Series VC_DSR_AGLN: Processing page 1 of 2
# ---Series VC_DSR_AGLN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_AGLN.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_AGLN.json
# series no. 348
# ---Series VC_DSR_BSDN: Processing page 1 of 2
# ---Series VC_DSR_BSDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_BSDN.json
# series no. 349
# ---Series VC_DSR_CDAN: Processing page 1 of 2
# ---Series VC_DSR_CDAN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_CDAN.json
# series no. 350
# ---Series VC_DSR_CDYN: Processing page 1 of 2
# ---Series VC_DSR_CDYN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_CDYN.json
# series no. 351
# ---Series VC_DSR_CHLN: Processing page 1 of 3
# ---Series VC_DSR_CHLN: Processing page 2 of 3
# ---Series VC_DSR_CHLN: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_CHLN.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_CHLN.json
# series no. 352
# ---Series VC_DSR_CILN: Processing page 1 of 3
# ---Series VC_DSR_CILN: Processing page 2 of 3
# ---Series VC_DSR_CILN: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_CILN.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_CILN.json
# series no. 353
# ---Series VC_DSR_DAFF: Processing page 1 of 4
# ---Series VC_DSR_DAFF: Processing page 2 of 4
# ---Series VC_DSR_DAFF: Processing page 3 of 4
# ---Series VC_DSR_DAFF: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_DAFF.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_DAFF.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_DAFF.json
# series no. 354
# ---Series VC_DSR_DDHN: Processing page 1 of 28
# ---Series VC_DSR_DDHN: Processing page 2 of 28
# ---Series VC_DSR_DDHN: Processing page 3 of 28
# ---Series VC_DSR_DDHN: Processing page 4 of 28
# ---Series VC_DSR_DDHN: Processing page 5 of 28
# ---Series VC_DSR_DDHN: Processing page 6 of 28
# ---Series VC_DSR_DDHN: Processing page 7 of 28
# ---Series VC_DSR_DDHN: Processing page 8 of 28
# ---Series VC_DSR_DDHN: Processing page 9 of 28
# ---Series VC_DSR_DDHN: Processing page 10 of 28
# ---Series VC_DSR_DDHN: Processing page 11 of 28
# ---Series VC_DSR_DDHN: Processing page 12 of 28
# ---Series VC_DSR_DDHN: Processing page 13 of 28
# ---Series VC_DSR_DDHN: Processing page 14 of 28
# ---Series VC_DSR_DDHN: Processing page 15 of 28
# ---Series VC_DSR_DDHN: Processing page 16 of 28
# ---Series VC_DSR_DDHN: Processing page 17 of 28
# ---Series VC_DSR_DDHN: Processing page 18 of 28
# ---Series VC_DSR_DDHN: Processing page 19 of 28
# ---Series VC_DSR_DDHN: Processing page 20 of 28
# ---Series VC_DSR_DDHN: Processing page 21 of 28
# ---Series VC_DSR_DDHN: Processing page 22 of 28
# ---Series VC_DSR_DDHN: Processing page 23 of 28
# ---Series VC_DSR_DDHN: Processing page 24 of 28
# ---Series VC_DSR_DDHN: Processing page 25 of 28
# ---Series VC_DSR_DDHN: Processing page 26 of 28
# ---Series VC_DSR_DDHN: Processing page 27 of 28
# ---Series VC_DSR_DDHN: Processing page 28 of 28
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_DDHN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_DDHN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_DDHN.json
# series no. 355
# ---Series VC_DSR_DDPA: Processing page 1 of 3
# ---Series VC_DSR_DDPA: Processing page 2 of 3
# ---Series VC_DSR_DDPA: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_DDPA.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_DDPA.json
# series no. 356
# ---Series VC_DSR_DYHN: Processing page 1 of 28
# ---Series VC_DSR_DYHN: Processing page 2 of 28
# ---Series VC_DSR_DYHN: Processing page 3 of 28
# ---Series VC_DSR_DYHN: Processing page 4 of 28
# ---Series VC_DSR_DYHN: Processing page 5 of 28
# ---Series VC_DSR_DYHN: Processing page 6 of 28
# ---Series VC_DSR_DYHN: Processing page 7 of 28
# ---Series VC_DSR_DYHN: Processing page 8 of 28
# ---Series VC_DSR_DYHN: Processing page 9 of 28
# ---Series VC_DSR_DYHN: Processing page 10 of 28
# ---Series VC_DSR_DYHN: Processing page 11 of 28
# ---Series VC_DSR_DYHN: Processing page 12 of 28
# ---Series VC_DSR_DYHN: Processing page 13 of 28
# ---Series VC_DSR_DYHN: Processing page 14 of 28
# ---Series VC_DSR_DYHN: Processing page 15 of 28
# ---Series VC_DSR_DYHN: Processing page 16 of 28
# ---Series VC_DSR_DYHN: Processing page 17 of 28
# ---Series VC_DSR_DYHN: Processing page 18 of 28
# ---Series VC_DSR_DYHN: Processing page 19 of 28
# ---Series VC_DSR_DYHN: Processing page 20 of 28
# ---Series VC_DSR_DYHN: Processing page 21 of 28
# ---Series VC_DSR_DYHN: Processing page 22 of 28
# ---Series VC_DSR_DYHN: Processing page 23 of 28
# ---Series VC_DSR_DYHN: Processing page 24 of 28
# ---Series VC_DSR_DYHN: Processing page 25 of 28
# ---Series VC_DSR_DYHN: Processing page 26 of 28
# ---Series VC_DSR_DYHN: Processing page 27 of 28
# ---Series VC_DSR_DYHN: Processing page 28 of 28
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_DYHN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_DYHN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_DYHN.json
# series no. 357
# ---Series VC_DSR_EFDN: Processing page 1 of 2
# ---Series VC_DSR_EFDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_EFDN.json
# series no. 358
# ---Series VC_DSR_ESDN: Processing page 1 of 2
# ---Series VC_DSR_ESDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_ESDN.json
# series no. 359
# ---Series VC_DSR_GDPLS: Processing page 1 of 3
# ---Series VC_DSR_GDPLS: Processing page 2 of 3
# ---Series VC_DSR_GDPLS: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_GDPLS.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_GDPLS.json
# series no. 360
# ---Series VC_DSR_HFDN: Processing page 1 of 2
# ---Series VC_DSR_HFDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_HFDN.json
# series no. 361
# ---Series VC_DSR_HOLH: Processing page 1 of 19
# ---Series VC_DSR_HOLH: Processing page 2 of 19
# ---Series VC_DSR_HOLH: Processing page 3 of 19
# ---Series VC_DSR_HOLH: Processing page 4 of 19
# ---Series VC_DSR_HOLH: Processing page 5 of 19
# ---Series VC_DSR_HOLH: Processing page 6 of 19
# ---Series VC_DSR_HOLH: Processing page 7 of 19
# ---Series VC_DSR_HOLH: Processing page 8 of 19
# ---Series VC_DSR_HOLH: Processing page 9 of 19
# ---Series VC_DSR_HOLH: Processing page 10 of 19
# ---Series VC_DSR_HOLH: Processing page 11 of 19
# ---Series VC_DSR_HOLH: Processing page 12 of 19
# ---Series VC_DSR_HOLH: Processing page 13 of 19
# ---Series VC_DSR_HOLH: Processing page 14 of 19
# ---Series VC_DSR_HOLH: Processing page 15 of 19
# ---Series VC_DSR_HOLH: Processing page 16 of 19
# ---Series VC_DSR_HOLH: Processing page 17 of 19
# ---Series VC_DSR_HOLH: Processing page 18 of 19
# ---Series VC_DSR_HOLH: Processing page 19 of 19
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_HOLH.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_HOLH.json
# series no. 362
# ---Series VC_DSR_HOLN: Processing page 1 of 3
# ---Series VC_DSR_HOLN: Processing page 2 of 3
# ---Series VC_DSR_HOLN: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_HOLN.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_HOLN.json
# series no. 363
# ---Series VC_DSR_HSDN: Processing page 1 of 2
# ---Series VC_DSR_HSDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_HSDN.json
# series no. 364
# ---Series VC_DSR_IJILN: Processing page 1 of 4
# ---Series VC_DSR_IJILN: Processing page 2 of 4
# ---Series VC_DSR_IJILN: Processing page 3 of 4
# ---Series VC_DSR_IJILN: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_IJILN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_IJILN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_IJILN.json
# series no. 365
# ---Series VC_DSR_LSGP: Processing page 1 of 3
# ---Series VC_DSR_LSGP: Processing page 2 of 3
# ---Series VC_DSR_LSGP: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.2_Series_VC_DSR_LSGP.json
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_LSGP.json
# series no. 366
# ---Series VC_DSR_MISS: Processing page 1 of 2
# ---Series VC_DSR_MISS: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_MISS.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_MISS.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_MISS.json
# series no. 367
# ---Series VC_DSR_MMHN: Processing page 1 of 28
# ---Series VC_DSR_MMHN: Processing page 2 of 28
# ---Series VC_DSR_MMHN: Processing page 3 of 28
# ---Series VC_DSR_MMHN: Processing page 4 of 28
# ---Series VC_DSR_MMHN: Processing page 5 of 28
# ---Series VC_DSR_MMHN: Processing page 6 of 28
# ---Series VC_DSR_MMHN: Processing page 7 of 28
# ---Series VC_DSR_MMHN: Processing page 8 of 28
# ---Series VC_DSR_MMHN: Processing page 9 of 28
# ---Series VC_DSR_MMHN: Processing page 10 of 28
# ---Series VC_DSR_MMHN: Processing page 11 of 28
# ---Series VC_DSR_MMHN: Processing page 12 of 28
# ---Series VC_DSR_MMHN: Processing page 13 of 28
# ---Series VC_DSR_MMHN: Processing page 14 of 28
# ---Series VC_DSR_MMHN: Processing page 15 of 28
# ---Series VC_DSR_MMHN: Processing page 16 of 28
# ---Series VC_DSR_MMHN: Processing page 17 of 28
# ---Series VC_DSR_MMHN: Processing page 18 of 28
# ---Series VC_DSR_MMHN: Processing page 19 of 28
# ---Series VC_DSR_MMHN: Processing page 20 of 28
# ---Series VC_DSR_MMHN: Processing page 21 of 28
# ---Series VC_DSR_MMHN: Processing page 22 of 28
# ---Series VC_DSR_MMHN: Processing page 23 of 28
# ---Series VC_DSR_MMHN: Processing page 24 of 28
# ---Series VC_DSR_MMHN: Processing page 25 of 28
# ---Series VC_DSR_MMHN: Processing page 26 of 28
# ---Series VC_DSR_MMHN: Processing page 27 of 28
# ---Series VC_DSR_MMHN: Processing page 28 of 28
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_MMHN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_MMHN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_MMHN.json
# series no. 368
# ---Series VC_DSR_MORT: Processing page 1 of 4
# ---Series VC_DSR_MORT: Processing page 2 of 4
# ---Series VC_DSR_MORT: Processing page 3 of 4
# ---Series VC_DSR_MORT: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_MORT.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_MORT.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_MORT.json
# series no. 369
# ---Series VC_DSR_MTMN: Processing page 1 of 5
# ---Series VC_DSR_MTMN: Processing page 2 of 5
# ---Series VC_DSR_MTMN: Processing page 3 of 5
# ---Series VC_DSR_MTMN: Processing page 4 of 5
# ---Series VC_DSR_MTMN: Processing page 5 of 5
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_MTMN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_MTMN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_MTMN.json
# series no. 370
# ---Series VC_DSR_MTMP: Processing page 1 of 4
# ---Series VC_DSR_MTMP: Processing page 2 of 4
# ---Series VC_DSR_MTMP: Processing page 3 of 4
# ---Series VC_DSR_MTMP: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_MTMP.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_MTMP.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_MTMP.json
# series no. 371
# ---Series VC_DSR_OBDN: Processing page 1 of 2
# ---Series VC_DSR_OBDN: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_11.5.2_Series_VC_DSR_OBDN.json
# series no. 372
# ---Series VC_DSR_PDAN: Processing page 1 of 4
# ---Series VC_DSR_PDAN: Processing page 2 of 4
# ---Series VC_DSR_PDAN: Processing page 3 of 4
# ---Series VC_DSR_PDAN: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_PDAN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_PDAN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_PDAN.json
# series no. 373
# ---Series VC_DSR_PDLN: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_PDLN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_PDLN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_PDLN.json
# series no. 374
# ---Series VC_DSR_PDYN: Processing page 1 of 3
# ---Series VC_DSR_PDYN: Processing page 2 of 3
# ---Series VC_DSR_PDYN: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_1.5.1_Series_VC_DSR_PDYN.json
# created file 2019.Q2.G.01\Indicator_11.5.1_Series_VC_DSR_PDYN.json
# created file 2019.Q2.G.01\Indicator_13.1.1_Series_VC_DSR_PDYN.json
# series no. 375
# ---Series VC_HTF_DETV: Processing page 1 of 2
# ---Series VC_HTF_DETV: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_16.2.2_Series_VC_HTF_DETV.json
# series no. 376
# ---Series VC_HTF_DETVFL: Processing page 1 of 3
# ---Series VC_HTF_DETVFL: Processing page 2 of 3
# ---Series VC_HTF_DETVFL: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_16.2.2_Series_VC_HTF_DETVFL.json
# series no. 377
# ---Series VC_HTF_DETVOG: Processing page 1 of 2
# ---Series VC_HTF_DETVOG: Processing page 2 of 2
# created file 2019.Q2.G.01\Indicator_16.2.2_Series_VC_HTF_DETVOG.json
# series no. 378
# ---Series VC_HTF_DETVOP: Processing page 1 of 3
# ---Series VC_HTF_DETVOP: Processing page 2 of 3
# ---Series VC_HTF_DETVOP: Processing page 3 of 3
# created file 2019.Q2.G.01\Indicator_16.2.2_Series_VC_HTF_DETVOP.json
# series no. 379
# ---Series VC_HTF_DETVSX: Processing page 1 of 4
# ---Series VC_HTF_DETVSX: Processing page 2 of 4
# ---Series VC_HTF_DETVSX: Processing page 3 of 4
# ---Series VC_HTF_DETVSX: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_16.2.2_Series_VC_HTF_DETVSX.json
# series no. 380
# ---Series VC_IHR_PSRC: Processing page 1 of 4
# ---Series VC_IHR_PSRC: Processing page 2 of 4
# ---Series VC_IHR_PSRC: Processing page 3 of 4
# ---Series VC_IHR_PSRC: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_16.1.1_Series_VC_IHR_PSRC.json
# series no. 381
# ---Series VC_IHR_PSRCN: Processing page 1 of 4
# ---Series VC_IHR_PSRCN: Processing page 2 of 4
# ---Series VC_IHR_PSRCN: Processing page 3 of 4
# ---Series VC_IHR_PSRCN: Processing page 4 of 4
# created file 2019.Q2.G.01\Indicator_16.1.1_Series_VC_IHR_PSRCN.json
# series no. 382
# ---Series VC_PRR_PHYV: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.3.1_Series_VC_PRR_PHYV.json
# series no. 383
# ---Series VC_PRR_ROBB: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.3.1_Series_VC_PRR_ROBB.json
# series no. 384
# ---Series VC_PRR_SEXV: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.3.1_Series_VC_PRR_SEXV.json
# series no. 385
# ---Series VC_PRS_UNSEC: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.3.2_Series_VC_PRS_UNSEC.json
# series no. 386
# ---Series VC_SNS_WALN: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.1.4_Series_VC_SNS_WALN.json
# series no. 387
# ---Series VC_VAW_MARR: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_5.2.1_Series_VC_VAW_MARR.json
# series no. 388
# ---Series VC_VAW_MTUHRA: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.10.1_Series_VC_VAW_MTUHRA.json
# series no. 389
# ---Series VC_VAW_PHYPYV: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.2.1_Series_VC_VAW_PHYPYV.json
# series no. 390
# ---Series VC_VAW_SXVLN: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.2.3_Series_VC_VAW_SXVLN.json
# series no. 391
# ---Series VC_VOV_PHYL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.1.3_Series_VC_VOV_PHYL.json
# series no. 392
# ---Series VC_VOV_ROBB: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.1.3_Series_VC_VOV_ROBB.json
# series no. 393
# ---Series VC_VOV_SEXL: Processing page 1 of 1
# created file 2019.Q2.G.01\Indicator_16.1.3_Series_VC_VOV_SEXL.json
