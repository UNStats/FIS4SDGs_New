# %% [markdown]
# # Data availability analysis by country

# %% [markdown]
# ## This is the plan:
# 1. Read metadata (catalogue of all series available)
# 2. Create a consolidated file with all the data
# 3. Split the consolidated file by country -- this will be James' request
# 4. Compute availability statistics by country series
#     - Number of "slices / disaggregations" available
#     - Latest year available
#     - Number of data points for the most aggregated slice
#     - Average no. of data points for the rest of the slices

# %% [markdown]
# ## Load necessary libraries

# %%
import os
import sys
import json
import urllib3  # allows to access a URL with python
import pandas as pd
import math
import os 
import hashlib
import csv
import copy
import unicodedata

# %%
os.path.abspath(os.curdir)
# Out:
# 'C:\\Users\\L.GonzalezMorales\\Documents\\GitHub\\FIS4SDGs\\notebooks\\unsdDataAvailability'

# %% [markdown]
# ## Setup interactive shell

# %%
# https://volderette.de/jupyter-notebook-tip-multiple-outputs/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Set path to data and metadata directories in the local branch:

# %%
release = '2019.Q2.G.01'

dir_path = os.path.dirname(os.path.realpath('__file__'))
print(dir_path)

data_dir = r'../../data/unsd/' + release + '/'
metadata_dir = r"../../globalResources/"
metadata_dir


print('data inputs dir: ' + data_dir)
# Out:
# C:\Users\L.GonzalezMorales\Documents\GitHub\FIS4SDGs\notebooks\unsdDataAvailability
# '../../globalResources/'
# data inputs dir: ../../data/unsd/2019.Q2.G.01/

# %% [markdown]
# ## Utilities

# %% [markdown]
# #### Convert string to camelCase

# %%
def camelCase(st, toAscii = True, startLowercase = True):
    """
    https://stackoverflow.com/questions/8347048/camelcase-every-string-any-standard-library
    
    """
    output = ''.join(x for x in st.title() if x.isalnum())
    if startLowercase:
        output = output[0].lower() + output[1:]
    
    if toAscii:
        output = unicodedata.normalize('NFD', output).encode('ascii', 'ignore').decode('utf-8')
        
    return output

# %% [markdown]
# ### Get data from a json file

# %%
def get_json_data(file, print_first_element = True):    
    
    """ Get json metadata file """
    
    try:
        json_data = json.load(open(file))
        if(print_first_element==True):
            print("\n----This is an example of a series_metadata element----")
            print(json_data[0])
        return json_data
    
    except:
        print("Unexpected error:", sys.exc_info()[0])
        return None

# %% [markdown]
# #### Print the tree structure of nested dictionaries

# %%
def jsonTree(d, depth=0):
  for x, v in d.items():
    print('-'*depth + x)
    if isinstance(v, list):
        v0 = v[0]
        if isinstance(v0, dict):
          jsonTree(v0, depth = depth+2)

# %% [markdown]
# #### Compute a hash of a dictionary

# %%
def dict_hash(d):
    out = hashlib.md5()
    for key, value in d.items():
        out.update(key.encode('utf-8'))
        out.update(str(value).encode('utf-8'))
    return out.hexdigest()

# %% [markdown]
# #### Get unique dictionaries in a list

# %%
def unique_dicts(dictionary_list):

    uniques_map = {}

    for d in dictionary_list:
        uniques_map[dict_hash(d)] = d

    return list(uniques_map.values())

# %% [markdown]
# #### Extract subset of key-value pairs from Python dictionary object

# %%
def subdict_list(dict_list, keys_list, exclude = False):
    sub_d_list = []
    if exclude:
        for d in dict_list:
            sub_d= {k: d[k] for k in d.keys() if k not in keys_list}
            sub_d_list.append(sub_d)
    else:
        for d in dict_list:
            sub_d= {k: d[k] for k in keys_list}
            sub_d_list.append(sub_d)
    
    return sub_d_list

# %% [markdown]
# #### Get a dict from a list based on something inside the dict

# %%
def select_dict(dict_list, k, v):
    selected = []
    for d in dict_list:
        if d[k] == v:
            selected.append(d)
    return selected

# %% [markdown]
# ### List of countries

# %%
def countryListXY(file):
    
    countryListXY = []
    
    with open(file, newline = '', encoding='latin-1') as countryList:                                                                                          
        countryList = csv.DictReader(countryList, delimiter='\t')
        for row in countryList:
            countryListXY.append(dict(row))
            
    countryListXY = pd.DataFrame(countryListXY).astype({'M49':'str'})
    
    return(countryListXY)

    #print(countryListXY[1])
    #for c in countryListXY:

# %%
countries_df = countryListXY(metadata_dir + 'refAreas.txt')
countries_df.head(10)

# %% [markdown]
# # 1. Read metadata

# %% [markdown]
# ## Get metadata file

# %%
series_metadata = get_json_data(metadata_dir + 'metadata.json', False)
jsonTree(series_metadata[0])
series_metadata[0]['code']

# %% [markdown]
# # 2. Create a consolidated file with all the data

# %% [markdown]
# ### Utilities

# %% [markdown]
# #### Re-arrange columns
# - Keep all dimenions together
# - Keep all value columns together
# - Push `value_latest_year` and `latest_year` to the end

# %%
def rearrange(bigtable):
    
    keys_1 = ['goal', 'target', 'indicator', 'seriesCode', 'seriesDesc', 'release',
       'geoAreaCode', 'geoAreaName', 'parentCode', 'parentName', 'type',
       'ISO3', 'UN_Member', 'X', 'Y']

    keys_2 = ['unitsCode', 'unitsDesc',
           'unitmultiplierCode', 'unitmultiplierDesc', 'reportingTypeCode',
           'reportingTypeDesc', 'valueDetails', 'footnotes', 'sources',
           'timeDetails', 'nature']

    keys_3 = ['value_latest_year', 'latest_year']
    
    value_cols = [x for x in list(bigtable.columns) if x.startswith('value_') and x != 'value_latest_year']
    value_cols = sorted(value_cols)
    
    dimension_cols = [x for x in list(bigtable.columns) if x not in keys_1 + keys_2 + keys_3 + value_cols]
    dimension_cols = sorted(dimension_cols)
    
    x =  bigtable[keys_1 + dimension_cols + keys_2 + value_cols + keys_3]
    
    x = x.sort_values(by= ['goal', 'target', 'indicator', 'seriesCode','geoAreaName'] + dimension_cols)
    
    return x

# %%
def split_by_country(bigtable, domain='', target_dir=''):
    
    country_catalog = bigtable[['geoAreaCode', 'geoAreaName']].drop_duplicates()
    
    for row in country_catalog.itertuples():

        geoAreaCode = row.geoAreaCode
        geoAreaName = camelCase(row.geoAreaName, startLowercase=False)
        
        
        country_table = bigtable.loc[bigtable['geoAreaCode'] == geoAreaCode]
        
        country_table = country_table.dropna(how='all', axis=1)
        
        country_table.to_excel(target_dir + 'Country_' +geoAreaName+'_'+ str(geoAreaCode) + '_' + domain + '.xlsx', index=False)

# %% [markdown]
# ## Merge all the data for each goal

# %%
for g in series_metadata:
    counter = 0
    #if g['code']!= '1':
    #    continue
    for t in g['targets']:
        #if t['code']!= '1.1':
        #    continue
        for i in t['indicators']:
            #if i['reference']!= '1.1.1':
            #    continue
            if 'series' in i.keys():
                for s in i['series']:
                    filename = 'csv_Indicator_' + i['reference'] + '_Series_' + s['code']+'.csv'
                    
                    if os.path.isfile(data_dir + filename):
                        small_table = pd.read_csv(data_dir + filename, sep='\t')
                        #drop empty rows:
                        small_table = small_table.dropna(subset=['value_latest_year'])
                    
                        if counter == 0:
                            big_table = copy.deepcopy(small_table)  
                        else:
                            big_table = pd.concat([big_table, small_table], ignore_index=True, sort=False)
                        counter = counter + 1
                        
                        #display('--'+str(counter) + ' - added series ' + s['code'])
                        
    big_table = rearrange(big_table)

    split_by_country(big_table, domain='Goal_' + g['code'], target_dir=data_dir)
    
    big_table.to_excel(data_dir + 'All_Countries_Goal_' + g['code']+'.xlsx', index=False)
    
    display('finished processing goal ' + g['code'])

# %% [markdown]
# ## get list of output files

# %%
import glob

path = data_dir

files = [f for f in glob.glob(path + '*.xlsx', recursive=False)]

for f in files:
    print(f)
# Out:
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\All_Countries_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Afghanistan_4_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AlandIslands_248_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AlandIslands_248_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AlandIslands_248_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Albania_8_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Algeria_12_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AmericanSamoa_16_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Andorra_20_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Angola_24_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Anguilla_660_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_AntiguaAndBarbuda_28_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Argentina_32_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Armenia_51_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Aruba_533_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Australia_36_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Austria_40_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Azerbaijan_31_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahamas_44_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bahrain_48_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bangladesh_50_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Barbados_52_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belarus_112_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belgium_56_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Belize_84_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Benin_204_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bermuda_60_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bhutan_64_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BoliviaPlurinationalStateOf_68_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BosniaAndHerzegovina_70_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Botswana_72_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BouvetIsland_74_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Brazil_76_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishIndianOceanTerritory_86_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishIndianOceanTerritory_86_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishIndianOceanTerritory_86_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishIndianOceanTerritory_86_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BritishVirginIslands_92_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BruneiDarussalam_96_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Bulgaria_100_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_BurkinaFaso_854_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Burundi_108_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaboVerde_132_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cambodia_116_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Cameroon_120_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Canada_124_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CaymanIslands_136_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CentralAfricanRepublic_140_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chad_148_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Chile_152_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaHongKongSpecialAdministrativeRegion_344_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChinaMacaoSpecialAdministrativeRegion_446_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_China_156_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChristmasIsland_162_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChristmasIsland_162_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChristmasIsland_162_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_ChristmasIsland_162_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CocosKeelingIslands_166_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CocosKeelingIslands_166_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CocosKeelingIslands_166_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_CocosKeelingIslands_166_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Colombia_170_Goal_6.xlsx
# ...
# ../../data/unsd/2019.Q2.G.01\Country_UnitedArabEmirates_784_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedArabEmirates_784_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedArabEmirates_784_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedArabEmirates_784_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedArabEmirates_784_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedKingdomOfGreatBritainAndNorthernIreland_826_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedRepublicOfTanzania_834_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesMinorOutlyingIslands_581_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesMinorOutlyingIslands_581_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesMinorOutlyingIslands_581_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesMinorOutlyingIslands_581_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesOfAmerica_840_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_UnitedStatesVirginIslands_850_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uruguay_858_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Uzbekistan_860_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Vanuatu_548_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VenezuelaBolivarianRepublicOf_862_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_VietNam_704_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WallisAndFutunaIslands_876_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_WesternSahara_732_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Yemen_887_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zambia_894_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_1.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_10.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_11.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_12.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_13.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_14.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_15.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_16.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_17.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_2.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_3.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_4.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_5.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_6.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_7.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_8.xlsx
# ../../data/unsd/2019.Q2.G.01\Country_Zimbabwe_716_Goal_9.xlsx
# ../../data/unsd/2019.Q2.G.01\dump_262_Goal_1.xlsx
